# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcos-VM-1708/PAD_JOB/blob/main/exploracao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nessa sessão você consegue avaliar a polaridade de uma frase

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

frase = pd.read_excel("/content/drive/MyDrive/Arquivos exportação/BD-Testes.xlsx")


display(frase)
# Out:
#                  COMERCIO                                         COMENTÁRIO  \
# 0    Nova Opção de Bilhar  Ambiente agradável, arejado e ventilado, atend...
# 1    Nova Opção de Bilhar  O atendimento e ruim o dono e homofobico racis...
# 2    Nova Opção de Bilhar  Lugar agradável, ambiente bom para encontrar c...
# 3    Nova Opção de Bilhar  Melhor lugar do mundo! Mais conhecido por mim ...
# 4    Nova Opção de Bilhar  Amei pagar 13$ na Antártica Litrão. Ficou até ...
# ..                    ...                                                ...
# 437           Zé Latinhas                                       Aconchegante
# 438           Zé Latinhas                                           Ótima!!!
# 439           Zé Latinhas                                       Ótima comida
# 440           Zé Latinhas                                                Boa
# 441           Zé Latinhas                                      Comida boa...
#
#                     DATA  AVALIACAO                SETOR  TextBlob Unnamed: 6
# 0              27/062023          4  Leste universitário       NaN        NaN
# 1    2019-06-24 00:00:00          1  Leste universitário       NaN        NaN
# 2    2023-04-05 00:00:00          3  Leste universitário       NaN        NaN
# 3    2023-01-15 00:00:00          5  Leste universitário       NaN        NaN
# 4    2023-06-26 00:00:00          5  Leste universitário       NaN        NaN
# ..                   ...        ...                  ...       ...        ...
# 437         3 anos atrás          4              Central       NaN        NaN
# 438         2 anos atrás          5              Central       NaN        NaN
# 439         3 anos atrás          5              Central       NaN        NaN
# 440         um ano atrás          1              Central       NaN        NaN
# 441         4 anos atrás          3              Central       NaN       29/7
#
# [442 rows x 7 columns]

# %%
tb = frase.loc[4, 'COMENTÁRIO']
print(tb)
# Out:
# Amei pagar 13$ na Antártica Litrão. Ficou até mais gostosa rsr

# %%
from textblob import TextBlob

tb = TextBlob(tb)
tb_en = tb.translate(from_lang='pt_br', to='en')
print(tb_en)
# Out:
# I loved to pay 13 $ in Antarctica Litrão. It was even hotter lol

# %%
polarity = tb_en.sentiment.polarity
print(f"Polaridade: {polarity}")
# Out:
# Polaridade: 0.75

# %% [markdown]
# # Tradução dos comentários

# %%
import pandas as pd

df = pd.read_excel("/content/drive/MyDrive/Arquivos exportação/BD-Testes.xlsx")


display(frase)
# Out:
#                  COMERCIO                                         COMENTÁRIO  \
# 0    Nova Opção de Bilhar  Ambiente agradável, arejado e ventilado, atend...
# 1    Nova Opção de Bilhar  O atendimento e ruim o dono e homofobico racis...
# 2    Nova Opção de Bilhar  Lugar agradável, ambiente bom para encontrar c...
# 3    Nova Opção de Bilhar  Melhor lugar do mundo! Mais conhecido por mim ...
# 4    Nova Opção de Bilhar  Amei pagar 13$ na Antártica Litrão. Ficou até ...
# ..                    ...                                                ...
# 437           Zé Latinhas                                       Aconchegante
# 438           Zé Latinhas                                           Ótima!!!
# 439           Zé Latinhas                                       Ótima comida
# 440           Zé Latinhas                                                Boa
# 441           Zé Latinhas                                      Comida boa...
#
#                     DATA  AVALIACAO                SETOR  TextBlob Unnamed: 6
# 0              27/062023          4  Leste universitário       NaN        NaN
# 1    2019-06-24 00:00:00          1  Leste universitário       NaN        NaN
# 2    2023-04-05 00:00:00          3  Leste universitário       NaN        NaN
# 3    2023-01-15 00:00:00          5  Leste universitário       NaN        NaN
# 4    2023-06-26 00:00:00          5  Leste universitário       NaN        NaN
# ..                   ...        ...                  ...       ...        ...
# 437         3 anos atrás          4              Central       NaN        NaN
# 438         2 anos atrás          5              Central       NaN        NaN
# 439         3 anos atrás          5              Central       NaN        NaN
# 440         um ano atrás          1              Central       NaN        NaN
# 441         4 anos atrás          3              Central       NaN       29/7
#
# [442 rows x 7 columns]

# %%
import pandas as pd
from textblob import TextBlob

# Suponha que este é o seu DataFrame original
#data = {'texto': ['Olá mundo', 'Como você está?', 'Estou bem']}
#df = pd.DataFrame(data)

# Função para traduzir texto
def traduzir(texto):
    try:
        return str(TextBlob(texto).translate(from_lang='pt_br', to='en'))
    except:
        return texto


# Aplicar a função de tradução para a coluna 'texto'
df['texto_traduzido'] = df['COMENTÁRIO'].apply(traduzir)

# Agora 'df' tem uma nova coluna 'texto_traduzido' com o texto traduzido
print(df)

# Para armazenar a coluna traduzida em outra tabela (novo DataFrame)
novo_df = df['texto_traduzido'].to_frame()
print(novo_df)
# Out:
#                  COMERCIO                                         COMENTÁRIO  \
# 0    Nova Opção de Bilhar  Ambiente agradável, arejado e ventilado, atend...
# 1    Nova Opção de Bilhar  O atendimento e ruim o dono e homofobico racis...
# 2    Nova Opção de Bilhar  Lugar agradável, ambiente bom para encontrar c...
# 3    Nova Opção de Bilhar  Melhor lugar do mundo! Mais conhecido por mim ...
# 4    Nova Opção de Bilhar  Amei pagar 13$ na Antártica Litrão. Ficou até ...
# ..                    ...                                                ...
# 437           Zé Latinhas                                       Aconchegante
# 438           Zé Latinhas                                           Ótima!!!
# 439           Zé Latinhas                                       Ótima comida
# 440           Zé Latinhas                                                Boa
# 441           Zé Latinhas                                      Comida boa...
#
#                     DATA  AVALIACAO                SETOR  TextBlob Unnamed: 6  \
# 0              27/062023          4  Leste universitário       NaN        NaN
# 1    2019-06-24 00:00:00          1  Leste universitário       NaN        NaN
# 2    2023-04-05 00:00:00          3  Leste universitário       NaN        NaN
# 3    2023-01-15 00:00:00          5  Leste universitário       NaN        NaN
# 4    2023-06-26 00:00:00          5  Leste universitário       NaN        NaN
# ..                   ...        ...                  ...       ...        ...
# 437         3 anos atrás          4              Central       NaN        NaN
# 438         2 anos atrás          5              Central       NaN        NaN
# 439         3 anos atrás          5              Central       NaN        NaN
# 440         um ano atrás          1              Central       NaN        NaN
# 441         4 anos atrás          3              Central       NaN       29/7
#
#                                        texto_traduzido
# 0    Nice, airy and ventilated environment, service...
# 1    The service is bad the owner and racist and ru...
# 2    Nice place, good environment to meet friends, ...
# 3    Best place in the world! Better known for me a...
# 4    I loved to pay 13 $ in Antarctica Litrão. It w...
# ..                                                 ...
# 437                                               Cozy
# 438                                       Excellent!!!
# 439                                         Great food
# 440                                               Good
# 441                                       Nice food...
#
# [442 rows x 8 columns]
#                                        texto_traduzido
# 0    Nice, airy and ventilated environment, service...
# 1    The service is bad the owner and racist and ru...
# 2    Nice place, good environment to meet friends, ...
# 3    Best place in the world! Better known for me a...
# 4    I loved to pay 13 $ in Antarctica Litrão. It w...
# ..                                                 ...
# 437                                               Cozy
# 438                                       Excellent!!!
# 439                                         Great food
# 440                                               Good
# 441                                       Nice food...
#
# [442 rows x 1 columns]

# %%
display(df)
# Out:
#                  COMERCIO                                         COMENTÁRIO  \
# 0    Nova Opção de Bilhar  Ambiente agradável, arejado e ventilado, atend...
# 1    Nova Opção de Bilhar  O atendimento e ruim o dono e homofobico racis...
# 2    Nova Opção de Bilhar  Lugar agradável, ambiente bom para encontrar c...
# 3    Nova Opção de Bilhar  Melhor lugar do mundo! Mais conhecido por mim ...
# 4    Nova Opção de Bilhar  Amei pagar 13$ na Antártica Litrão. Ficou até ...
# ..                    ...                                                ...
# 437           Zé Latinhas                                       Aconchegante
# 438           Zé Latinhas                                           Ótima!!!
# 439           Zé Latinhas                                       Ótima comida
# 440           Zé Latinhas                                                Boa
# 441           Zé Latinhas                                      Comida boa...
#
#                     DATA  AVALIACAO                SETOR  TextBlob Unnamed: 6  \
# 0              27/062023          4  Leste universitário       NaN        NaN
# 1    2019-06-24 00:00:00          1  Leste universitário       NaN        NaN
# 2    2023-04-05 00:00:00          3  Leste universitário       NaN        NaN
# 3    2023-01-15 00:00:00          5  Leste universitário       NaN        NaN
# 4    2023-06-26 00:00:00          5  Leste universitário       NaN        NaN
# ..                   ...        ...                  ...       ...        ...
# 437         3 anos atrás          4              Central       NaN        NaN
# 438         2 anos atrás          5              Central       NaN        NaN
# 439         3 anos atrás          5              Central       NaN        NaN
# 440         um ano atrás          1              Central       NaN        NaN
# 441         4 anos atrás          3              Central       NaN       29/7
#
#                                        texto_traduzido
# 0    Nice, airy and ventilated environment, service...
# 1    The service is bad the owner and racist and ru...
# 2    Nice place, good environment to meet friends, ...
# 3    Best place in the world! Better known for me a...
# 4    I loved to pay 13 $ in Antarctica Litrão. It w...
# ..                                                 ...
# 437                                               Cozy
# 438                                       Excellent!!!
# 439                                         Great food
# 440                                               Good
# 441                                       Nice food...
#
# [442 rows x 8 columns]

# %% [markdown]
# # Exportar

# %%
# Exportar DataFrame como CSV
df.to_csv('dataset-Traduzido.csv', index=False)
