# %%
import pandas as pd

file_path = 'C:/Users/moura/PAD_JOB/data_extracted/New-dataset-SVCpredictions.csv'
dataset = pd.read_csv(file_path)


dataset.head()
# Out:
#    title                                               text     stars  \
# 0  BOB'S   Shake e Sunday aguados. Horrível. Não recomendo.  negative
# 1  BOB'S                                             Credo!  negative
# 2  BOB'S                  Desorganizado, pedido veio errado  negative
# 3  BOB'S                                Atendimento péssimo  negative
# 4  BOB'S  Todos atendentes de mal humor e sem educação, ...  negative
#
#    likesCount                                   reviewerPhotoUrl  \
# 0           1  https://lh3.googleusercontent.com/a-/AD_cMMRso...
# 1           0  https://lh3.googleusercontent.com/a-/AD_cMMS7i...
# 2           0  https://lh3.googleusercontent.com/a-/AD_cMMQP2...
# 3           0  https://lh3.googleusercontent.com/a-/AD_cMMSwu...
# 4           2  https://lh3.googleusercontent.com/a-/AD_cMMS_z...
#
#                     publishedAtDate                             name  \
# 0  2021-04-03 20:10:01.702000+00:00                     Sílvio Brito
# 1  2019-05-25 21:11:05.280000+00:00                     Tiago de Bem
# 2  2020-02-15 23:29:17.166000+00:00                paulo aecio alves
# 3  2018-10-18 10:25:35.416000+00:00  Eryka Ferreira Menezes de Paula
# 4  2022-01-15 18:37:15.511000+00:00                      João Benuto
#
#   predictions
# 0    negative
# 1    negative
# 2    negative
# 3    negative
# 4    negative

# %%
dataset.iloc[2].at['text']
# Out:
# 'Desorganizado, pedido veio errado'

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89212 entries, 0 to 89211
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             89212 non-null  object
#  1   text              89212 non-null  object
#  2   stars             89212 non-null  object
#  3   likesCount        89212 non-null  int64
#  4   reviewerPhotoUrl  89212 non-null  object
#  5   publishedAtDate   89212 non-null  object
#  6   name              89212 non-null  object
#  7   predictions       89212 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 5.4+ MB

# %%
import pandas as pd

def map_sentiment(totalScore):
    if totalScore <= 2:
        return "negativo"
    elif totalScore == 3:
        return "neutro"
    else:
        return "positivo"
    
sentiment = dataset['totalScore'].apply(map_sentiment)


dataset = pd.DataFrame({
    'title' : dataset['title'],
    'categoryName': dataset['categoryName'],
    'postalCode' : dataset['postalCode'],
    'address' : dataset['address'],
    'reviews': dataset['reviews'],  
    'SENTIMENTO': sentiment,
    'totalScore': dataset['totalScore'],
    'texto': dataset['texto']
    #'TextBlob': dataset['TextBlob'],    
    #'texto_traduzido': dataset['texto_traduzido']
})

# %%
display(dataset)
# Out:
#                                                    title  \
# 0                                                  BOB'S
# 1                                                  BOB'S
# 2                                                  BOB'S
# 3                                                  BOB'S
# 4                                                  BOB'S
# ...                                                  ...
# 89207  Cabaça de Mel - Restaurante e Buffet para Casa...
# 89208  Cabaça de Mel - Restaurante e Buffet para Casa...
# 89209  Cabaça de Mel - Restaurante e Buffet para Casa...
# 89210  Cabaça de Mel - Restaurante e Buffet para Casa...
# 89211  Cabaça de Mel - Restaurante e Buffet para Casa...
#
#                                                     text     stars  \
# 0       Shake e Sunday aguados. Horrível. Não recomendo.  negative
# 1                                                 Credo!  negative
# 2                      Desorganizado, pedido veio errado  negative
# 3                                    Atendimento péssimo  negative
# 4      Todos atendentes de mal humor e sem educação, ...  negative
# ...                                                  ...       ...
# 89207  Comida deliciosa, muita variedade, e ambiente ...  positive
# 89208                           Comida boa preços bons!!  positive
# 89209                   Um ótimo lugar para se alimentar  positive
# 89210  Excelente local. Fico Grato a Deus por ter um ...  positive
# 89211            Comida caseira, feita no fogão a lenha.  positive
#
#        likesCount                                   reviewerPhotoUrl  \
# 0               1  https://lh3.googleusercontent.com/a-/AD_cMMRso...
# 1               0  https://lh3.googleusercontent.com/a-/AD_cMMS7i...
# 2               0  https://lh3.googleusercontent.com/a-/AD_cMMQP2...
# 3               0  https://lh3.googleusercontent.com/a-/AD_cMMSwu...
# 4               2  https://lh3.googleusercontent.com/a-/AD_cMMS_z...
# ...           ...                                                ...
# 89207           0  https://lh3.googleusercontent.com/a-/AD_cMMRJl...
# 89208           0  https://lh3.googleusercontent.com/a/AAcHTtdGik...
# 89209           1  https://lh3.googleusercontent.com/a-/AD_cMMQ1g...
# 89210           0  https://lh3.googleusercontent.com/a-/AD_cMMQ6-...
# 89211           0  https://lh3.googleusercontent.com/a/AAcHTtdz18...
#
#                         publishedAtDate  \
# 0      2021-04-03 20:10:01.702000+00:00
# 1      2019-05-25 21:11:05.280000+00:00
# 2      2020-02-15 23:29:17.166000+00:00
# 3      2018-10-18 10:25:35.416000+00:00
# 4      2022-01-15 18:37:15.511000+00:00
# ...                                 ...
# 89207  2017-11-20 22:46:09.936000+00:00
# 89208  2021-02-24 21:25:14.976000+00:00
# 89209  2018-11-13 01:15:01.320000+00:00
# 89210  2016-05-20 18:20:27.050000+00:00
# 89211  2019-11-12 04:08:12.573000+00:00
#
#                                           name predictions
# 0                                 Sílvio Brito    negative
# 1                                 Tiago de Bem    negative
# 2                            paulo aecio alves    negative
# 3              Eryka Ferreira Menezes de Paula    negative
# 4                                  João Benuto    negative
# ...                                        ...         ...
# 89207                         Bruno Cavalcante    positive
# 89208                           Marcos Pereira    positive
# 89209                 Atonilson Costa Ferreira    negative
# 89210  Dinastia Contabil Contabilidade Goiânia    positive
# 89211                              Luiz Carlos    positive
#
# [89212 rows x 8 columns]

# %% [markdown]
# Análise de Sentimentos por Comércio

# %%
# Agrupando o dataset por comércio e calculando a média da avaliação e da pontuação de sentimento (TextBlob)
analise_comercio = dataset.groupby('categoryName')[['totalScore']].mean()

# Ordenando os comércios pela média da avaliação
analise_comercio.sort_values('totalScore', ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Agrupando o dataset por comércio e calculando a média da avaliação e da pontuação de sentimento (TextBlob)
# ----> 2 analise_comercio = dataset.groupby('categoryName')[['totalScore']].mean()
#       4 # Ordenando os comércios pela média da avaliação
#       5 analise_comercio.sort_values('totalScore', ascending=False).head(10)
#
# File c:\Users\moura\Anaconda3\envs\PAD\lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# File c:\Users\moura\Anaconda3\envs\PAD\lib\site-packages\pandas\core\groupby\groupby.py:965, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     962 if grouper is None:
#     963     from pandas.core.groupby.grouper import get_grouper
# --> 965     grouper, exclusions, obj = get_grouper(
#     966         obj,
#     967         keys,
#     968         axis=axis,
#     969         level=level,
#     970         sort=sort,
#     971         observed=observed,
#     972         mutated=self.mutated,
#     973         dropna=self.dropna,
#     974     )
#     976 self.obj = obj
#     977 self.axis = obj._get_axis_number(axis)
#
# File c:\Users\moura\Anaconda3\envs\PAD\lib\site-packages\pandas\core\groupby\grouper.py:888, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886         in_axis, level, gpr = False, gpr, None
#     887     else:
# --> 888         raise KeyError(gpr)
#     889 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890     # Add key to exclusions
#     891     exclusions.add(gpr.key)
#
# KeyError: 'categoryName'

# %%
# Agrupando o dataset por comércio e calculando a média da avaliação
analise_comercio_avaliacao = dataset.groupby('categoryName')['totalScore'].mean().reset_index()

# Ordenando os comércios pela média da avaliação
top_comercios = analise_comercio_avaliacao.sort_values('totalScore', ascending=False).head(5)
bottom_comercios = analise_comercio_avaliacao.sort_values('totalScore').head(5)

#top_comercios, bottom_comercios

# %%
print(top_comercios)
# Out:
#           categoryName  totalScore
# 2    Bar com tabacaria         5.0
# 12            Chop bar         5.0
# 16  Quadra de esportes         4.9
# 8        Bar esportivo         4.8
# 25               Salão         4.8

# %%
print(bottom_comercios)
# Out:
#                 categoryName  totalScore
# 18    Restaurante brasileiro    4.246341
# 24           Saladas prontas    4.300000
# 4            Bar de narguilé    4.300000
# 23  Restaurante self-service    4.300000
# 14                 Gastropub    4.349630

# %%
# Selecionando comentários para o comércio com a maior avaliação média
comercio_maior_avaliacao = top_comercios.iloc[0]['categoryName']

comentarios_maior_avaliacao = dataset[dataset['categoryName'] == comercio_maior_avaliacao][['texto', 'totalScore']]



sample = comentarios_maior_avaliacao.sample(5, replace=True)
print(sample)
# Out:
#                                     texto  totalScore
# 32  A melhor boate da região.super indico         5.0
# 33       Super indico em qualquer ocasião         5.0
# 32  A melhor boate da região.super indico         5.0
# 32  A melhor boate da região.super indico         5.0
# 32  A melhor boate da região.super indico         5.0
